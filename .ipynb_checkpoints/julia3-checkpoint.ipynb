# %% [markdown]
# # Julia 3

# %% [markdown]
# # Arreglos y Dataframes

# %%
using LinearAlgebra

# %%
[1,2,3]
# Out:
# 3-element Array{Int64,1}:
#  1
#  2
#  3

# %%
[1 2 3]
# Out:
# 1×3 Array{Int64,2}:
#  1  2  3

# %%
[1 2 3]'
# Out:
# 3×1 Adjoint{Int64,Array{Int64,2}}:
#  1
#  2
#  3

# %%
A1=Real[1 2 3]
# Out:
# 1×3 Array{Real,2}:
#  1  2  3

# %%
A2=Complex[1 2 3]
# Out:
# 1×3 Array{Complex,2}:
#  1+0im  2+0im  3+0im

# %% [markdown]
# # Visualización

# %% [markdown]
# # El paquete Colors

# %%
using Colors

# %% [markdown]
# Colores con nombre propio [colores](http://juliagraphics.github.io/Colors.jl/stable/namedcolors/)

# %%
Colors.color_names
# Out:
# Dict{String,Tuple{Int64,Int64,Int64}} with 666 entries:
#   "darkorchid"      => (153, 50, 204)
#   "chocolate"       => (210, 105, 30)
#   "chocolate2"      => (238, 118, 33)
#   "grey69"          => (176, 176, 176)
#   "grey97"          => (247, 247, 247)
#   "olivedrab3"      => (154, 205, 50)
#   "deeppink2"       => (238, 18, 137)
#   "mediumpurple2"   => (159, 121, 238)
#   "ivory1"          => (255, 255, 240)
#   "gray95"          => (242, 242, 242)
#   "darkgoldenrod4"  => (139, 101, 8)
#   "lemonchiffon2"   => (238, 233, 191)
#   "palegreen4"      => (84, 139, 84)
#   "cornsilk4"       => (139, 136, 120)
#   "red1"            => (255, 0, 0)
#   "wheat1"          => (255, 231, 186)
#   "lightpink4"      => (139, 95, 101)
#   "wheat2"          => (238, 216, 174)
#   "purple2"         => (145, 44, 238)
#   "grey22"          => (56, 56, 56)
#   "seashell4"       => (139, 134, 130)
#   "lightcyan1"      => (224, 255, 255)
#   "mediumvioletred" => (199, 21, 133)
#   "gray14"          => (36, 36, 36)
#   "lemonchiffon"    => (255, 250, 205)
#   ⋮                 => ⋮

# %%
colorant"red"
# Out:
# RGB{N0f8}(1.0,0.0,0.0)

# %%
parse(Colorant, "DeepSkyBlue")
# Out:
# RGB{N0f8}(0.0,0.749,1.0)

# %%
colorant"rgb(225,100,35)"
# Out:
# RGB{N0f8}(0.882,0.392,0.137)

# %%
RGB.(colormatch.(350:10:750))
# Out:
# 41-element Array{RGB{Float64},1} with eltype RGB{Float64}:
#  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.00145678358615866,0.0,0.008361993276931724)
#  RGB{Float64}(0.004590181387371799,0.0,0.02684671096007028)
#  RGB{Float64}(0.014954446709146313,0.0,0.07756798947365434)
#  RGB{Float64}(0.04580728065959692,0.0,0.1576510417733637)
#  RGB{Float64}(0.11170792576114436,0.0,0.29839790246587555)
#  RGB{Float64}(0.20825949725024484,0.0,0.5079174083880983)
#  RGB{Float64}(0.36147747268035174,0.0,0.8484369655603431)
#  RGB{Float64}(0.4971024738719369,0.0,1.0)
#  RGB{Float64}(0.5087895027290269,0.0,1.0)
#  RGB{Float64}(0.42034638193497353,0.0,1.0)
#  RGB{Float64}(0.14258349671751575,0.0,1.0)
#  RGB{Float64}(0.0,0.20546402569979505,1.0)
#  ⋮
#  RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(0.883002437831568,0.0,0.0)
#  RGB{Float64}(0.6947762659135557,0.0,0.0)
#  RGB{Float64}(0.521032274073289,0.0,0.0)
#  RGB{Float64}(0.3892001721243109,0.0,0.0)
#  RGB{Float64}(0.2738191272441103,0.0,0.0)
#  RGB{Float64}(0.19145149910188922,0.0,0.0)
#  RGB{Float64}(0.13112187341715448,0.0,0.0)
#  RGB{Float64}(0.08451718449995763,0.0,0.0)
#  RGB{Float64}(0.049228043989301855,0.0,0.0)
#  RGB{Float64}(0.02394222233082155,0.0,0.0)
#  RGB{Float64}(0.011529160387062289,0.0,0.0)

# %%
range(colorant"red", stop=colorant"green", length=20)
# Out:
# 20-element Array{RGB{N0f8},1} with eltype RGB{FixedPointNumbers.Normed{UInt8,8}}:
#  RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.949,0.027,0.0)
#  RGB{N0f8}(0.894,0.055,0.0)
#  RGB{N0f8}(0.843,0.078,0.0)
#  RGB{N0f8}(0.788,0.106,0.0)
#  RGB{N0f8}(0.737,0.133,0.0)
#  RGB{N0f8}(0.682,0.161,0.0)
#  RGB{N0f8}(0.631,0.184,0.0)
#  RGB{N0f8}(0.58,0.212,0.0)
#  RGB{N0f8}(0.525,0.239,0.0)
#  RGB{N0f8}(0.475,0.263,0.0)
#  RGB{N0f8}(0.42,0.29,0.0)
#  RGB{N0f8}(0.369,0.318,0.0)
#  RGB{N0f8}(0.318,0.341,0.0)
#  RGB{N0f8}(0.263,0.369,0.0)
#  RGB{N0f8}(0.212,0.396,0.0)
#  RGB{N0f8}(0.157,0.424,0.0)
#  RGB{N0f8}(0.106,0.447,0.0)
#  RGB{N0f8}(0.051,0.475,0.0)
#  RGB{N0f8}(0.0,0.502,0.0)

# %%
colormap("Purples", 20)
# Out:
# 20-element Array{RGB{Float64},1} with eltype RGB{Float64}:
#  RGB{Float64}(0.9832222643034968,0.9827093133143204,0.9862383669967713)
#  RGB{Float64}(0.9609051488530461,0.9571356205557823,0.9837907789729686)
#  RGB{Float64}(0.9367403457563394,0.9297895428095794,0.9803597831743723)
#  RGB{Float64}(0.9106007691703044,0.9005609778997579,0.9757652939464255)
#  RGB{Float64}(0.8823611180125324,0.8693338958843493,0.969800450138547)
#  RGB{Float64}(0.8519023545224211,0.8359857830530752,0.9622279547577796)
#  RGB{Float64}(0.8191179593722243,0.8003868693452986,0.952775862247535)
#  RGB{Float64}(0.7839225576153882,0.762399039685743,0.9411326746058646)
#  RGB{Float64}(0.7462636839714993,0.7218742831187425,0.9269415409691402)
#  RGB{Float64}(0.7061376435422219,0.6786524583396867,0.9097932449949023)
#  RGB{Float64}(0.6636105576919297,0.6325580240263595,0.8892174766950606)
#  RGB{Float64}(0.618845569049737,0.583395138534963,0.8646715557767147)
#  RGB{Float64}(0.5721363018170226,0.5309400353728903,0.8355251718409501)
#  RGB{Float64}(0.523943770530636,0.47492846456486787,0.8010385525237225)
#  RGB{Float64}(0.4749260728460047,0.4150332227346833,0.7603291088068017)
#  RGB{Float64}(0.4259311704104119,0.3508190684756788,0.7123163452795289)
#  RGB{Float64}(0.3778815055087798,0.2816371308149106,0.6556217013986277)
#  RGB{Float64}(0.3313988121109341,0.20631784484648025,0.5883618703747237)
#  RGB{Float64}(0.28587016934066545,0.12189640170657198,0.5076369086244045)
#  RGB{Float64}(0.2372084274466012,0.015563492773514565,0.4078280032523798)

# %% [markdown]
# # LaTeX

# %%
using Latexify
using LaTeXStrings
# Out:
# ┌ Info: Precompiling Latexify [23fbe1c1-3f47-55db-b15f-69d7ec21a316]
# └ @ Base loading.jl:1278

# %%
using Latexify
ex = :(x/(y+x)^2)
latexify(ex)
# Out:
# L"$\frac{x}{\left( y + x \right)^{2}}$"

# %%
arr = ["x/y" 3//7 2+3im; 1 :P_x :(gamma(3))]
latexify(arr)
# Out:
# L"\begin{equation}
# \left[
# \begin{array}{ccc}
# \frac{x}{y} & \frac{3}{7} & 2+3\textit{i} \\
# 1 & P_{x} & \Gamma\left( 3 \right) \\
# \end{array}
# \right]
# \end{equation}
# "

# %%
print(latexify("x+y/(b-2)^2"))
# Out:
# $x + \frac{y}{\left( b - 2 \right)^{2}}$

# %%
L"1+\alpha^2"
# Out:
# L"$1+\alpha^2$"

# %% [markdown]
# # Paquetes Plots y StatsPlots

# %%
using Plots, StatsPlots
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling StatsPlots [f3b207a7-027a-5e70-b257-86293d7955fd]
# └ @ Base loading.jl:1278

# %%
x = 1:10; y = rand(10);

# %%
plot(x,y)

# %%
x=1:10; y=rand(10,2);
plot(x,y)

# %%
plot(x, y, title = "Dos Líneas", label = ["Línea 1" "Línea 2"], lw = 3)

# %%
scatter(x,y,title="Diagrama de dispersión")

# %%
y = rand(10, 4)
plot(x, y, layout = (4, 1))

# %%
p1 = plot(x, y) 
p2 = scatter(x, y) 
p3 = plot(x, y, xlabel = "Título eje x", lw = 3, title = "Subtítulo")
p4 = histogram(x,y) 
plot(p1, p2, p3, p4, layout = (2, 2), legend = false)

# %%
boxplot(x,y)

# %%
z=randn(1000);
histogram(z,color=colormap("Greens",15))

# %%
using Distributions
n = 1000
x = rand(Gamma(2), n)
y = -0.5x + randn(n)
marginalhist(x, y, fc = :plasma, bins = 40)

# %%
using LaTeXStrings
x=0:0.1:2*π
y=sin.(x).^2
plot(x, y, label=L"$\sin(x)^2$")

# %%
x_vals = [0 0 0 ; 2 -3 -4]
y_vals = [0 0 0 ; 4 3 -3.5]

plot(x_vals, y_vals, arrow = true, color = :blue,
     legend = :none, xlims = (-5, 5), ylims = (-5, 5),
     annotations = [(2.2, 4.4, "[2, 4]"),
                    (-3.3, 3.3, "[-3, 3]"),
                    (-4.4, -3.85, "[-4, -3.5]")],
     xticks = -5:1:5, yticks = -5:1:5,
     framestyle = :origin)
